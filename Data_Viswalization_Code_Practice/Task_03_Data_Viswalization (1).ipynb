# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('/content/iris.csv')
iris.head(10)
iris.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
iris.sample(5)
# Out:
# <ipython-input-18-c7d964f8b483>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 133  134            6.3           2.8            5.1           1.5        2
# 92    93            5.8           2.6            4.0           1.2        1
# 53    54            5.5           2.3            4.0           1.3        1
# 131  132            7.9           3.8            6.4           2.0        2
# 41    42            4.5           2.3            1.3           0.3        0

# %%
plt.figure(figsize=(15,7))
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet')
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.colorbar()

# %%
df1 = pd.read_csv('/content/batter.csv')
df1.head()
df = df1.head(100).sample(25,random_state=5)

# %%
df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.scatter(df['avg'],df['strike_rate'])
plt.xlabel('Avg')
plt.ylabel('Strike-Rate')
# Out:
# Text(0, 0.5, 'Strike-Rate')

# %%
x =[1,2,3,4,5]
y=[6,7,8,3,9]
plt.scatter(x,y)
plt.text(1,5,'point 1')
plt.text(2,6,'point 2')
plt.text(3,7,'point 3')
plt.text(4,8,'point 4')
# Out:
# Text(4, 8, 'point 4')

# %%
plt.scatter(df['avg'],df['strike_rate'],s=df['runs'])

plt.axhline(130,color='red')
plt.axvline(30,color='blue')

for i in range(df.shape[0]):
  plt.text(df['avg'].values[i],df['strike_rate'].values[i],df['batter'].values[i])

# %%
iris = pd.read_csv('/content/iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
# Out:
# <ipython-input-66-17f24f7015cf>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df3 = df2['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame (Replace this with actual iris DataFrame)
# new_iris = iris.head(10)

plt.scatter(new_iris['SepalLengthCm'], new_iris['PetalLengthCm'])

# Add text labels for each point
for i in range(new_iris.shape[0]):
    plt.text(new_iris['SepalLengthCm'].values[i],
             new_iris['PetalLengthCm'].values[i],
             str(new_iris['Species'].values[i]))  # Fixed indexing

# Labels for the plot
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.title('Scatter plot of Sepal vs Petal Length (First 10 Samples)')

plt.show()

# %%
fig,ax = plt.subplots(figsize=(15,6))

ax.scatter(df['avg'],df['strike_rate'],color='red')
ax.set_xlabel('Avg')
ax.set_ylabel('Strike_rate')
fig.show()

# %%
fig ,ax = plt.subplots(nrows=2,ncols=1,sharex=True)
ax[0].scatter(df1['avg'],df1['strike_rate'])
ax[1].scatter(df1['runs'],df1['strike_rate'])


ax[0].set_title('Avg VS Strike_Rate')
ax[0].set_xlabel('average')
ax[0].set_ylabel('Strike_Rate')


ax[1].set_title('Strike_Rate vs runs')
ax[1].set_xlabel('average')
ax[1].set_ylabel('Strike_Rate')
# Out:
# Text(0, 0.5, 'Strike_Rate')

# %%
a = pd.read_csv('/content/placement.csv')
a.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
b = pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022.csv')
b.sample(10)
# Out:
#              ID  innings  overs  ballnumber      batter          bowler  \
# 141271   598032        2      0           3   AM Rahane        DW Steyn
# 24446   1254090        1     12           1  GJ Maxwell   Harpreet Brar
# 85707   1082606        2      6           1      N Rana       RA Jadeja
# 22442   1254099        2      3           5   SS Tiwary    Ravi Bishnoi
# 175362   501236        1      6           2  MEK Hussey    DT Christian
# 87226   1082600        2     16           3   KH Pandya     BCJ Cutting
# 212778   336039        1     10           3   PP Chawla  M Muralitharan
# 60898   1175357        2      4           2  RV Uthappa          S Kaul
# 137464   598048        2      4           3  MA Agarwal        I Sharma
# 109733   829769        2     14           7   SPD Smith  MJ McClenaghan
#
#            non-striker extra_type  batsman_run  extras_run  total_run  \
# 141271        R Dravid        NaN            0           0          0
# ...

# %%
gov = pd.read_csv('/content/RS_Session_266_AU_1529_B_2.csv')
gov.head(5)
# Out:
#               State                  Beneficiary Agencies and Projects  \
# 0  Himachal Pradesh  Irrigation Department (Sewerage Project for Zo...
# 1     Uttar Pradesh      Hybrid Annuity Mode (HAM) Projects at Mathura
# 2     Uttar Pradesh         Hybrid Annuity Mode (HAM) Projects at Agra
# 3     Uttar Pradesh  Mathura Audhyogik Chettra and PradushanNivaran...
# 4             Delhi  Delhi Jal Board (Construction and Rehabilitati...
#
#    2019-20  2020-21  2021-22  2022-23  2023-24    Total
# 0      NaN     1.25     2.50      NaN      NaN     3.75
# 1    52.29    25.63    94.01    13.88    46.68   232.49
# 2      NaN      NaN      NaN    20.65    71.00    91.65
# 3      NaN      NaN     1.63     7.89     0.19     9.71
# 4   214.47   235.00   405.00    75.40   161.18  1091.05

# %%
plt.scatter(gov['State'],gov['Total'])

# %%
fd = pd.read_csv('/content/batter.csv')
fd.sample(7)
# Out:
#                       batter  runs        avg  strike_rate
# 536                 A Uniyal     4   4.000000    57.142857
# 313              KA Jamieson    65  16.250000   118.181818
# 275           Mohammed Siraj    96  13.714286    86.486486
# 166                 B Chipli   280  18.666667   109.375000
# 498  JPR Scantlebury-Searles     8   8.000000   133.333333
# 120              JP Faulkner   527  20.269231   129.802956
# 409              BMAJ Mendis    23   7.666667    85.185185

# %%
fig ,ax = plt.subplots(nrows=2,ncols=2,figsize=(5,5))

ax[0,0].scatter(fd['avg'],fd['strike_rate'])
ax[0,0].set_title('Avegare vs Srtrike rate')
ax[0,0].set_xlabel('Avegare')
ax[0,0].set_ylabel('Strike Rate')


ax[1,0].scatter(fd['runs'],fd['strike_rate'])
ax[1,0].set_title('Runs vs Srtrike rate')
ax[1,0].set_xlabel('Runs')
ax[1,0].set_ylabel('Strike Rate')

ax[0,1].scatter(fd['runs'],fd['strike_rate'])
ax[0,1].set_title('Runs vs Srtrike rate')
ax[0,1].set_xlabel('Runs')
ax[0,1].set_ylabel('Strike Rate')


ax[1,1].scatter(fd['runs'],fd['strike_rate'])
ax[1,1].set_title('Runs vs Srtrike rate')
ax[1,1].set_xlabel('Runs')
ax[1,1].set_ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/iris.csv')
df.sample(20)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 129  130            7.2           3.0            5.8           1.6
# 54    55            6.5           2.8            4.6           1.5
# 45    46            4.8           3.0            1.4           0.3
# 30    31            4.8           3.1            1.6           0.2
# 72    73            6.3           2.5            4.9           1.5
# 119  120            6.0           2.2            5.0           1.5
# 71    72            6.1           2.8            4.0           1.3
# 143  144            6.8           3.2            5.9           2.3
# 10    11            5.4           3.7            1.5           0.2
# 7      8            5.0           3.4            1.5           0.2
# 116  117            6.5           3.0            5.5           1.8
# 2      3            4.7           3.2            1.3           0.2
# 100  101            6.3           3.3            6.0           2.5
# ...

# %%
df['Species'] = df['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
# Out:
# <ipython-input-6-a334adec311e>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Species'] = df['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})

# %%
df['Species']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'],cmap='viridis',c=df['Species'])
# plt.figure(figsize=(15,7))
plt.colorbar()
plt.title('Scatter plot of Iris Dataset')
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.show()

# %%
df = pd.read_csv('/content/batter.csv')
df.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
x = [1,2,3,4,5]
y = [6,4,3,2,1]

plt.scatter(x,y)
plt.text(1,5,'point 1')
plt.text(3,4,'point 2')
# Out:
# Text(3, 4, 'point 2')

# %%
# we done the work in loop

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
batters = pd.read_csv('/content/batter.csv')

# %%
batters.head(5)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
sample_df = batters.head(100).sample(25,random_state=5)
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
# annotation
plt.scatter(sample_df['avg'],sample_df['strike_rate'])

for i in range(sample_df.shape[0]):
  plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

plt.axhline(120,color ='red')
plt.axhline(140,color = 'blue')
plt.axvline(22.5,color = 'red')

# %%
fig,ax = plt.subplots(nrows=2,ncols=1)
ax[0].scatter(batters['strike_rate'],batters['avg'])
ax[1].scatter(batters['strike_rate'],batters['runs'])

# %%
# 3D Scatter plot

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')
ax.scatter3D(batters['runs'],batters['avg'],batters['strike_rate'])

# %%
fig = plt.figure()

ax =plt.subplot(projection='3d')

ax.scatter3D(batters['strike_rate'],batters['avg'],batters['runs'])

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(batters['avg'],batters['strike_rate'],batters['runs'])

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(batters['avg'])

# %%
new = pd.read_csv('/content/iris.csv')
new.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(new['SepalLengthCm'],new['PetalLengthCm'],new['Id'])

# %%
x = [1,2,3,4,5,6,7]
y = [5,2,3,6,1,3,8]
z = [9,2,4,7,1,4,3]


fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(x,y,z,s=[100]*len(x))
ax.plot(x,y,z,color='red')

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7]
y = [5, 2, 3, 6, 1, 3, 8]
z = [9, 2, 4, 7, 1, 4, 3]

fig = plt.figure()
ax = plt.subplot(projection='3d')

ax.scatter3D(x, y, z, s=[100] * len(x))  # Corrected size list

plt.show()

# %%
new.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(new['SepalLengthCm'],new['PetalLengthCm'],new['PetalWidthCm'])

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

# %%
xx,yy = np.meshgrid(x,y)

# %%
# z = xx**2 + yy**
z = np.sin(xx) + np.cos(yy)

# %%
z.shape
# Out:
# (100, 100)

# %%
fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')

p = ax.plot_surface(xx,yy,z,cmap='viridis')

fig.colorbar(p)

# %%
fig = plt.figure()

ax = plt.subplot(projection='3d')

ax.scatter3D(batters['runs'],batters['strike_rate'],batters['avg'])

# %%
fig = plt.figure()

ax = plt.subplot()

ax.contourf(xx,yy,z)
# fig.colorbar(p)

# %%
import numpy as np

# %%
aa = np.linspace(-10,10,100)
cc = np.linspace(-10,10,100)

# %%
xx,yy = np.meshgrid(x,y)

# %%
z = xx**2 + yy**2

# %%
z.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-26a7f04225ae> in <cell line: 0>()
# ----> 1 z.shape()
#
# TypeError: 'tuple' object is not callable

# %%
delivery = pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022.csv')
delivery
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
temp_df = delivery[(delivery['ballnumber'].isin([1,2,3,4,5,6])) & (delivery['batsman_run']==6)]

# %%
grid = temp_df.pivot_table(index='overs',columns = 'ballnumber',values='batsman_run',aggfunc='count')

# %%
plt.figure(figsize=(5,20))
plt.imshow(grid)
plt.colorbar()

# %%
# PLOTTING IN PANDAS

# %%
x =pd.Series([1,2,3,4,5,6,7])

# x.plot(kind='bar')
x.plot(kind='pie')
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['size'] = tips['size']*100

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner   200
# 1       10.34  1.66    Male     No  Sun  Dinner   300
# 2       21.01  3.50    Male     No  Sun  Dinner   300
# 3       23.68  3.31    Male     No  Sun  Dinner   200
# 4       24.59  3.61  Female     No  Sun  Dinner   400

# %%
tips.plot(kind='scatter',x = 'total_bill',y = 'tip',marker='+',figsize=(5,5),s='size',c='sex',cmap='viridis')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
stock = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')
stock.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
# LINE PLOT

# %%
stock['MSFT'].plot(kind='line')
# Out:
# <Axes: >

# %%
stock.plot(kind='line',x='Date')
# Out:
# <Axes: xlabel='Date'>

# %%
stock[['Date','FB',	'AAPL']].plot(kind='line')
# Out:
# <Axes: >

# %%
stock[['FB','AAPL']].plot(kind='line')
